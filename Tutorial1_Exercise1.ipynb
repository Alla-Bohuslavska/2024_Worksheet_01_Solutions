# %% [markdown]
# Solution exercise 1:

# %%
library("datasets")
data(faithful)
plot(faithful$waiting, faithful$eruptions, , xlab="Waiting time (mins)", ylab="Eruption time (mins)", main="Scatterplot")

hist(faithful$waiting, freq=FALSE, col = "lightskyblue3", xlab="Waiting time (mins)", ylab = "Relative frequency", main = "Histogram of waiting time")
hist(faithful$eruptions, freq=FALSE, col = "lightskyblue3", xlab="Eruption time (mins)", ylab = "Relative frequency", main = "Histogram of eruption time (mins)")
# Out:
# Plot with title “Scatterplot”
# Plot with title “Histogram of waiting time”
# Plot with title “Histogram of eruption time (mins)”
