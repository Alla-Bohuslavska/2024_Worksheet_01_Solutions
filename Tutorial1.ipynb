# %% [markdown]
# 1. The dataset $\texttt{faithful}$ in the package $\texttt{dataset}$ includes measurements of the eruption and waiting times between eruptions for the Old Faithful geyser in Yellowstone National Park.
#     1. Load the data and display the scatterplot with the waiting time on the x-axis.
#     2. Is the data collected from an observational or an experimental study?
#     3. Is there an association between the waiting time and the measurements of the eruption?
#     4. Discuss any particularity of the data. Consider the histograms of each sample.

# %%
# Answer

# %% [markdown]
# 2. The dataset $\texttt{aravo}$ in the package $\texttt{ade4}$ consists of four dataframes about various characteristics of Alpine plants in Aravo (Valloire, France). One of the dataframes, $\texttt{env}$, includes 6 environmental measurements of the sites in Aravo.
#    1. Load the data env.
#    2.  Describe the type of each variable in the dataset env.
#    3.  The variable Form indicates the topographic index of the land, with values: 1 = convexity, 2 = convex slope, 3 = right slope, 4 = concave slope, 5 = concavity. The variable ZoogD indicates the quantity of unvegetated soil due to marmot activity, with values: no, some, high.
#
#         Complete the contingency table for the two variables.
#
#         ![Table.png](attachment:a8a0a592-a682-4c6d-b1b2-88ee8441e7e3.png)
#     4. What is the proportion of high unvegetable soil sites in the right slope group?

# %%
# Answer

# %% [markdown]
# 3. A research team investigates the effect of diet on early growth of chicken. 49 randomly selected chickens were assigned randomly to 4 different diets. Their weights are measures from birth, every second day, until day 20, with an extra measurement on day 21. Below is the histogram of the chicken weights on day 8.
#    ![Tutorial1_Exercise3.png](attachment:26973ffb-4277-4f22-bd32-c36cd4189d3e.png)
#     1. Estimate the median of this sample of weights.
#     2. How would you expect the mean weight value to be compared to the median? Justify your answer.
#     3. Confirm your guess by loading the dataset $\texttt{ChickWeight}$ in the package $\texttt{datasets}$. To access only the weights in the 8th day, you may use the command:
#
#        `x <- ChickWeight$weight[ChickWeight$Time==8]`

# %%
# Answer

# %% [markdown]
# 4. To test the effectiveness of various insecticides, a team of entomologists has conducted an experiment. 72 controlled areas were treated with a specific insecticide, labelled A, B, C, D, E and F and the number of insects was counted after the treatment. The data is available in $\texttt{InsectSprays}$ in the package $\texttt{datasets}$.
#
#    We focus on the insect counts for insecticides A and C. You can get the information using the following command:
#
#     `x <- InsectSprays$count[InsectSprays$spray=='A']`
#
#     `y <- InsectSprays$count[InsectSprays$spray=='C']`
#
#     1. Plot relative frequency histograms of the insect counts for insecticides A and C separately. Be sure to use the same intervals.
#     2. Compute the sample mean and sample standard deviation for insect counts for insecticides A and C, respectively.
#     3. Plot the boxplots side by side for the insect counts for insecticides A and C. What do you notice? You may use the command:
#
#     `data <- data.frame(x,y)`
#
#     `boxplot(data)`

# %%
# Answer
